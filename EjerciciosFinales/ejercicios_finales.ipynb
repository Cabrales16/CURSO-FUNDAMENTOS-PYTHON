# %% [markdown]
# # Ejercicios para aplicar funciones, estructuras de control, colecciones, módulos y manejo de excepciones
#
# ---
#
# ## Ejercicio 1: Calculadora Avanzada
#
# **Descripción:**
# Crea una función que actúe como calculadora. La función recibirá dos números y un operador (por ejemplo, '+', '-', '*', '/', '**', '//') para realizar la operación correspondiente.
# - Utiliza estructuras de control (if/else) para seleccionar la operación a realizar.
# - Usa manejo de excepciones para controlar errores como la división por cero y entradas no numéricas.
# - Puedes importar el módulo `math` para operaciones adicionales si es necesario.
#
# **Ejemplo de salida:**
#
# Ingrese el primer número: 10
# Ingrese el segundo número: 5
# Ingrese el operador (+, -, *, /, **, //): /
# Resultado: 10 / 5 = 2.0

# %%
import math

operacion = input('Ingrese la operación a realizar: ')
if operacion == 'suma':
    a = float(input('Ingrese el primer número: '))
    b = float(input('Ingrese el segundo número: '))
    resultado = a + b
elif operacion == 'resta':
    a = float(input('Ingrese el primer número: '))
    b = float(input('Ingrese el segundo número: '))
    resultado = a - b
elif operacion == 'multiplicacion':
    a = float(input('Ingrese el primer número: '))
    b = float(input('Ingrese el segundo número: '))
    resultado = a * b
elif operacion == 'division':
    a = float(input('Ingrese el primer número: '))
    b = float(input('Ingrese el segundo número: '))
    if b == 0:
        resultado = 'Error: No se puede dividir entre cero'
    else:
        resultado = a / b
elif operacion == 'potencia':
    a = float(input('Ingrese la base: '))
    b = float(input('Ingrese el exponente: '))
    resultado = a ** b
elif operacion == 'raiz':
    a = float(input('Ingrese el número: '))
    if a < 0:
        resultado = 'Error: No se puede sacar la raiz de cuadrada de un número negativo'
    else:
        resultado = math.sqrt(a)
else:
    resultado = 'Error: Operación no válida'

print(f'El resultado de la {operacion} es: {resultado}')
# Out:
# El resultado de la raiz es: 2.0

# %% [markdown]
# ---
#
# ## Ejercicio 2: Administrador de Inventarios
#
# **Descripción:**
# Desarrolla un sistema para gestionar el inventario de productos usando un diccionario donde cada clave es el nombre del producto y su valor la cantidad en stock.
# - Implementa funciones para agregar, actualizar y eliminar productos.
# - Utiliza estructuras de control para recorrer y mostrar el inventario.
# - Incluye manejo de excepciones para capturar intentos de actualizar o eliminar un producto inexistente.
#
# **Ejemplo de salida:**
# Inventario inicial: {'manzanas': 50, 'naranjas': 30, 'peras': 20}
# Actualizando stock de 'peras' a 25...
# Producto 'bananas' agregado con 40 unidades.
# Eliminando 'naranjas'...
# Inventario final: {'manzanas': 50, 'peras': 25, 'bananas': 40}

# %%
inventario = {
    'manzanas': 10,
    'peras': 5,
    'naranjas': 8
}

def agregar_producto(producto, cantidad):
    if producto in inventario:
        inventario[producto] += cantidad
    else:
        inventario[producto] = cantidad
    print(f'Se han agregado {cantidad} unidades de {producto}.')
    print(f'Inventario actualizado: {inventario}')

def eliminar_producto(producto, cantidad):
    if producto in inventario:
        if inventario[producto] >= cantidad:
            inventario[producto] -= cantidad
            print(f'Se han eliminado {cantidad} unidades de {producto}.')
        else:
            print(f'Error: No hay suficientes unidades de {producto} para eliminar.')
    else:
        print(f'Error: El producto {producto} no existe en el inventario.')
    print(f'Inventario actualizado: {inventario}')

def mostrar_inventario():
    print('Inventario actual:')
    for producto, cantidad in inventario.items():
        print(f'{producto}: {cantidad} unidades')

    else:
        print(f'Error: El producto {producto} no existe en el inventario.')

opcion = input('Que quiere hacer? (agregar, eliminar, mostrar, salir): ')
while opcion != 'salir':
    if opcion == 'agregar':
        producto = input('Ingrese el nombre del producto: ')
        cantidad = int(input('Ingrese la cantidad a agregar: '))
        agregar_producto(producto, cantidad)
    elif opcion == 'eliminar':
        producto = input('Ingrese el nombre del producto: ')
        cantidad = int(input('Ingrese la cantidad a eliminar: '))
        eliminar_producto(producto, cantidad)
    elif opcion == 'mostrar':
        mostrar_inventario()
    else:
        print('Opción no válida. Intente de nuevo.')
    opcion = input('Que quiere hacer? (agregar, eliminar, mostrar, salir): ')
    print('Gracias por usar el sistema.')
# Out:
# Se han agregado 10 unidades de manzana.
# Inventario actualizado: {'manzanas': 10, 'peras': 5, 'naranjas': 8, 'manzana': 10}
# Gracias por usar el sistema.
# Se han eliminado 4 unidades de peras.
# Inventario actualizado: {'manzanas': 10, 'peras': 1, 'naranjas': 8, 'manzana': 10}
# Gracias por usar el sistema.
# Se han agregado 20 unidades de peras.
# Inventario actualizado: {'manzanas': 10, 'peras': 21, 'naranjas': 8, 'manzana': 10}
# Gracias por usar el sistema.
# Se han agregado 20 unidades de manzanas.
# Inventario actualizado: {'manzanas': 30, 'peras': 21, 'naranjas': 8, 'manzana': 10}
# Gracias por usar el sistema.

# %% [markdown]
# ---
#
# ## Ejercicio 3: Análisis de Texto
#
# **Descripción:**
# Crea una función que reciba una cadena de texto y calcule la frecuencia de cada palabra en el mismo.
# - Convierte el texto a minúsculas y separa las palabras usando algún método (puedes utilizar expresiones regulares con el módulo `re`).
# - Emplea un diccionario para almacenar la palabra (clave) y su frecuencia (valor).
# - Controla excepciones en caso de que el usuario no ingrese ningún texto o ingrese caracteres inesperados.
#
# **Ejemplo de salida:**
# Ingrese un texto: "Hola mundo, hola a todos en el mundo"
# Frecuencia de palabras: hola: 2
# mundo: 2
# a: 1
# todos: 1
# en: 1
# el: 1

# %%
# # **Ejemplo de salida:**  
# # Ingrese un texto: "Hola mundo, hola a todos en el mundo"
# # Frecuencia de palabras: hola: 2
# # mundo: 2
# # a: 1
# # todos: 1
# # en: 1
# # el: 1
frase = input('Ingrese un texto (unicamente texto): ')
palabras = frase.split()
caracteres_no_permitidos = ['!', '#', '$', '%', '&', '*', '(', ')', '-', '=', '+', '{', '}', '[', ']', ':', ';', ',', '?']
frecuencia = {}
def contar_frecuencia(palabras):
    for palabra in palabras:
        palabra = palabra.lower()
        if palabra in frecuencia:
            frecuencia[palabra] += 1
        else:
            frecuencia[palabra] = 1
    return frecuencia

try:
    if frase == '':
        raise ValueError('No puede dejar el espacio vacio')
    if frase.isnumeric():
        raise Exception('La frase no puede contener números o caracteres especiales')
    for letr in caracteres_no_permitidos:
        if letr in frase:
            raise Exception('La frase contiene caracteres no permitidos')
except ValueError as e:
    print(e)
except Exception as e:
    print(e)
else:
    frecuencia = contar_frecuencia(palabras)
    print(f'Frecuencia de palabras: {frecuencia}')
finally:
    print('Gracias por usar el programa')
# Out:
# Frecuencia de palabras: {'hola': 3}
# Gracias por usar el programa

# %% [markdown]
# ---
#
# ## Ejercicio 4: Conversor de Unidades
#
# **Descripción:**
# Desarrolla un conjunto de funciones para convertir unidades métricas. Por ejemplo:
# - De centímetros a pulgadas.
# - De kilómetros a millas.
# Utiliza estructuras de control para verificar que la entrada sea numérica, y maneja excepciones cuando el usuario ingrese datos inválidos.
#
# **Ejemplo de salida:**
# Seleccione la conversión:
#
# Centímetros a pulgadas
#
# Kilómetros a millas
# Opción: 1
# Ingrese la cantidad en centímetros: 100
# Resultado: 100 cm = 39.37 pulgadas

# %%
def centimetros_pulgadas(centimetros):
    pulgadas = centimetros / 2.54
    return pulgadas

def kilometros_millas(kilometros):
    millas = kilometros / 1.60934
    return millas

print(f'Opciones:\n1: Centimetros a pulgadas\n2: Kilometros a millas')
opcion = int(input('Ingrese la opción deseada: '))

try:
    if opcion == 1:
        centimetros = float(input('Ingrese la cantidad en centimetros: '))
        resultado = centimetros_pulgadas(centimetros)
        print(f'{centimetros} centimetros son {resultado:.2f} pulgadas')
    elif opcion == 2:
        kilometros = float(input('Ingrese la cantidad en kilometros: '))
        resultado = kilometros_millas(kilometros)
        print(f'{kilometros} kilometros son {resultado:.2f} millas')
    else:
        print('Opción no válida. Por favor, elija la 1 o la 2')

except ValueError:
    print('Error: Por favor, ingrese un número válido.')

except Exception as e:
    print(f'Error inesperado: {e}')

finally:
    print('Gracias por usar el programa')
# Out:
# Opciones:
# 1: Centimetros a pulgadas
# 2: Kilometros a millas
# 123.1 centimetros son 48.46 pulgadas
# Gracias por usar el programa

# %% [markdown]
# ---
#
# ## Ejercicio 5: Juego "Adivina el Número"
#
# **Descripción:**
# Implementa un juego en el que la computadora selecciona aleatoriamente un número en un rango (por ejemplo, 1 a 50) y el usuario debe adivinarlo.
# - Emplea el módulo `random` para generar el número secreto.
# - Utiliza un bucle que permita múltiples intentos, con retroalimentación indicando si el número ingresado es mayor o menor que el secreto.
# - Gestiona excepciones para capturar entradas no numéricas.
#
# **Ejemplo de salida:**
# ¡Bienvenido al juego "Adivina el Número"!
# Estoy pensando en un número entre 1 y 50.
# Intento 1 - Ingresa tu número: 25
# El número secreto es mayor.
# Intento 2 - Ingresa tu número: 35
# El número secreto es menor.
# Intento 3 - Ingresa tu número: 30
# ¡Felicidades! Has adivinado el número secreto: 30

# %%
import random

def adivina_numero():
    numero_secreto = random.randint(1, 50)
    intentos = 0
    print("¡Bienvenido al juego 'Adivina el Número'!")
    print("Estoy pensando en un número entre 1 y 50.")

    while True:
        intentos += 1
        try:
            numero_usuario = int(input(f"Intento {intentos} - Ingresa tu número: "))
            if numero_usuario < numero_secreto:
                print("El número secreto es mayor.")
            elif numero_usuario > numero_secreto:
                print("El número secreto es menor.")
            else:
                print(f"¡Felicidades! Has adivinado el número secreto: {numero_secreto}")
                break
        except ValueError:
            print("Por favor, ingresa un número válido.")

adivina_numero()
# Out:
# ¡Bienvenido al juego 'Adivina el Número'!
# Estoy pensando en un número entre 1 y 50.
# El número secreto es mayor.
# El número secreto es mayor.
# El número secreto es mayor.
# El número secreto es mayor.
# El número secreto es mayor.
# El número secreto es mayor.
# El número secreto es menor.
# El número secreto es menor.
# El número secreto es menor.
# El número secreto es mayor.
# ¡Felicidades! Has adivinado el número secreto: 32

# %% [markdown]
# ---
#
# ## Ejercicio 6: Calculadora de Factorial
#
# **Descripción:**
# Crea una función que calcule el factorial de un número entero ingresado por el usuario.
# - La función debe utilizar estructuras de control para iterar (o una solución recursiva) y calcular el factorial.
# - Implementa manejo de excepciones para asegurarte de que el número ingresado es entero y no negativo.
#
# **Ejemplo de salida:**
# Ingrese un número entero para calcular su factorial: 5
# El factorial de 5 es 120

# %%
def factorial(n):
    resultado = 1
    for i in range(2, n + 1):
        resultado *= i
    return resultado

try:
    numero = int(input("Ingrese un número entero no negativo: "))
    if numero < 0:
        print("Error: El número debe ser un entero no negativo.")
    else:
        print(f"El factorial de {numero} es {factorial(numero)}")
except ValueError:
    print("Error: Por favor, ingrese un número válido.")
# Out:
# Error: Por favor, ingrese un número entero válido.

# %% [markdown]
# ---
#
# ## Ejercicio 7: Manejo de Fechas y Horas
#
# **Descripción:**
# Desarrolla una función que reciba una fecha ingresada por el usuario en formato "DD/MM/AAAA" y determine cuántos días faltan para esa fecha a partir de hoy.
# - Importa el módulo `datetime` para trabajar con fechas.
# - Utiliza estructuras de control para validar el formato y maneja excepciones en caso de error en el ingreso de la fecha.
#
# **Ejemplo de salida:**
# Ingrese una fecha (DD/MM/AAAA): 25/12/2023
# Faltan 150 días para el 25/12/2023.

# %%
import datetime

def determ_fecha_restante(fecha_objetivo):
    fecha_actual = datetime.datetime.now()
    diferencia = fecha_objetivo - fecha_actual
    return diferencia.days

try:
    fecha_str = input("Ingrese una fecha futura (YYYY-MM-DD): ")
    fecha_objetivo = datetime.datetime.strptime(fecha_str, "%Y-%m-%d")
    if fecha_objetivo < datetime.datetime.now():
        raise ValueError("La fecha debe ser futura.")
    dias_restantes = determ_fecha_restante(fecha_objetivo)
    print(f"Días restantes hasta {fecha_str}: {dias_restantes} días")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error inesperado: {e}")
finally:
    print("Gracias por usar el programa")
# Out:
# Días restantes hasta 2025-04-18: 1 días
# Gracias por usar el programa

# %% [markdown]
# ---
#
# ## Ejercicio 8: Registro de Estudiantes
#
# **Descripción:**
# Implementa un sistema que gestione un registro de estudiantes utilizando un diccionario, donde la clave sea el nombre y el valor la calificación.
# - Crea funciones para agregar un estudiante, actualizar la calificación, eliminar estudiantes y listar todo el registro.
# - Utiliza un bucle para mostrar un menú interactivo al usuario.
# - Maneja excepciones para gestionar errores en la selección de opciones o al intentar modificar un estudiante inexistente.
#
# **Ejemplo de salida:**
# Registro de estudiantes inicial: {'Ana': 90, 'Luis': 78, 'Carlos': 85}
#
# Menú:
#
# Agregar estudiante
#
# Actualizar calificación
#
# Eliminar estudiante
#
# Listar estudiantes
#
# Salir
#
# Opción: 2
# Ingrese el nombre del estudiante: Luis
# Ingrese la nueva calificación: 82
# Estudiante actualizado: Luis - 82
#
# Registro final: {'Ana': 90, 'Luis': 82, 'Carlos': 85}

# %%
def mostrar_estudiantes(estudiantes):
    print("Lista de estudiantes y sus notas:")
    for nombre, nota in estudiantes.items():
        print(f"{nombre}: {nota}")

def agregar_estudiante(estudiantes, nombre, nota):
    if nombre in estudiantes:
        print(f"El estudiante {nombre} ya existe.")
    else:
        estudiantes[nombre] = nota
        print(f"Estudiante {nombre} agregado con nota {nota}.")

def eliminar_estudiante(estudiantes, nombre):
    if nombre in estudiantes:
        del estudiantes[nombre]
        print(f"Estudiante {nombre} eliminado.")
    else:
        print(f"El estudiante {nombre} no existe.")

def modificar_nota(estudiantes, nombre, nueva_nota):
    if nombre in estudiantes:
        estudiantes[nombre] = nueva_nota
        print(f"Nota de {nombre} modificada a {nueva_nota}.")
    else:
        print(f"El estudiante {nombre} no existe.")

estudiantes = {
    'Andres': 50,
    'Juan': 60,
    'Maria': 70,
    'Ana': 80,
    'Luis': 90,
}

print('Opciones:\n1: Mostrar estudiantes\n2: Agregar estudiante\n3: Eliminar estudiante\n4: Modificar nota\n5: Salir')
opcion = int(input('Ingrese la opción deseada: '))

while opcion != 5:
    try:
        if opcion == 1:
            mostrar_estudiantes(estudiantes)
        elif opcion == 2:
            nombre = input('Ingrese el nombre del estudiante: ')
            nota = int(input('Ingrese la nota del estudiante: '))
            agregar_estudiante(estudiantes, nombre, nota)
        elif opcion == 3:
            nombre = input('Ingrese el nombre del estudiante a eliminar: ')
            eliminar_estudiante(estudiantes, nombre)
        elif opcion == 4:
            nombre = input('Ingrese el nombre del estudiante: ')
            nueva_nota = int(input('Ingrese la nueva nota: '))
            modificar_nota(estudiantes, nombre, nueva_nota)
        else:
            print('Opción no válida. Por favor, elija una opción válida.')
    except ValueError:
        print('Error: Por favor, ingrese un número válido.')
    except Exception as e:
        print(f'Error inesperado: {e}')
    finally:
        print('Gracias por usar el programa')
        if opcion == 5:
            print('Saliendo del programa...')
            break
        else:
            print('Opciones:\n1: Mostrar estudiantes\n2: Agregar estudiante\n3: Eliminar estudiante\n4: Modificar nota\n5: Salir')
            opcion = int(input('Ingrese la opción deseada: '))
# Out:
# Opciones:
# 1: Mostrar estudiantes
# 2: Agregar estudiante
# 3: Eliminar estudiante
# 4: Modificar nota
# 5: Salir
# Lista de estudiantes y sus notas:
# Andres: 50
# Juan: 60
# Maria: 70
# Ana: 80
# Luis: 90
# Gracias por usar el programa
# Opciones:
# 1: Mostrar estudiantes
# 2: Agregar estudiante
# 3: Eliminar estudiante
# 4: Modificar nota
# 5: Salir
# El estudiante Isaac no existe.
# Gracias por usar el programa
# Opciones:
# 1: Mostrar estudiantes
# 2: Agregar estudiante
# 3: Eliminar estudiante
# 4: Modificar nota
# 5: Salir
# El estudiante Isaac no existe.
# Gracias por usar el programa
# Opciones:
# 1: Mostrar estudiantes
# 2: Agregar estudiante
# 3: Eliminar estudiante
# 4: Modificar nota
# 5: Salir

# %% [markdown]
# ---
#
# ## Ejercicio 9: Generador de Contraseñas Aleatorias
#
# **Descripción:**
# Crea una función que genere una contraseña aleatoria de una longitud especificada por el usuario.
# - Utiliza el módulo `random` junto con la biblioteca `string` para construir la contraseña a partir de letras (mayúsculas y minúsculas), dígitos y caracteres especiales.
# - Valida la entrada y maneja excepciones para asegurarte de que la longitud es un número entero positivo.
#
# **Ejemplo de salida:**
# Ingrese la longitud deseada para la contraseña: 10
# Contraseña generada: A8b#K3d!Qz

# %%
import random
import string

def generar_contrasena(longitud_clave):
    caracteres = string.ascii_letters + string.digits
    caracteres = ''.join(random.sample(caracteres, longitud_clave - 2))  # Asegurarse de que la contraseña contenga al menos dos caracteres especiales
    caracteres_especiales = ''.join(random.choices(string.punctuation, k=2))
    caracteres = caracteres + caracteres_especiales
    # Asegurarse de que la contraseña contenga al menos un carácter especial
    clave = ''.join(random.sample(caracteres, longitud_clave))
    return clave

try:
    longitud_clave = int(input("Ingrese la longitud de la contraseña (mínimo 8): "))
    if longitud_clave < 8:
        raise ValueError("La longitud mínima de la contraseña es 8.")
    if longitud_clave is not None and longitud_clave < 8:
        raise ValueError("La longitud mínima de la contraseña es 8.")
    clave_generada = generar_contrasena(longitud_clave)
    print(f"Contraseña generada: {clave_generada}")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error inesperado: {e}")
finally:
    print("Gracias por usar el generador de contraseñas.")
# Out:
# Error: invalid literal for int() with base 10: '-'
# Gracias por usar el generador de contraseñas.

# %% [markdown]
# ---
#
# ## Ejercicio 10: Buscador de Archivos en un Directorio
#
# **Descripción:**
# Desarrolla una función que reciba el nombre de un directorio y una subcadena para buscar archivos cuyo nombre la contenga.
# - Utiliza el módulo `os` para listar el contenido del directorio.
# - Aplica estructuras de control para filtrar los archivos según la subcadena.
# - Implementa manejo de excepciones para controlar errores como directorio no existente o permisos insuficientes.
#
# **Ejemplo de salida:**
# Ingrese la ruta del directorio: /ruta/al/directorio
# Ingrese la subcadena a buscar: reporte
# Archivos encontrados que contienen "reporte":
#
# reporte_enero.pdf
#
# reporte_febrero.xlsx
#
# resumen_reporte.txt

# %%
# Ejemplo de salida:**
# Ingrese la ruta del directorio: /ruta/al/directorio
# Ingrese la subcadena a buscar: reporte
# Archivos encontrados que contienen "reporte":
import os

def buscar_archivos(directorio, subcadena):
    archivos_encontrados = []
    for root, dirs, files in os.walk(directorio):
        for file in files:
            if subcadena in file:
                archivos_encontrados.append(os.path.join(root, file))
    return archivos_encontrados

try:
    directorio = input("Ingrese la ruta del directorio: ")
    subcadena = input("Ingrese la subcadena a buscar: ")
    if not os.path.isdir(directorio):
        raise ValueError("La ruta ingresada no es un directorio válido.")
    archivos_encontrados = buscar_archivos(directorio, subcadena)
    if archivos_encontrados:
        print(f"Archivos encontrados que contienen '{subcadena}':")
        for archivo in archivos_encontrados:
            print(archivo)
    else:
        print(f"No se encontraron archivos que contengan '{subcadena}'.")
except ValueError as e:
    print(f"Error: {e}")
except Exception as e:
    print(f"Error inesperado: {e}")
finally:
    print("Gracias por usar el buscador de archivos.")
# Out:
# Archivos encontrados que contienen 'archivo':
# C:\Users\andre\OneDrive\Escritorio\Workspace\Python\EjerciciosFinales\ejemplo_directorio\archivo1.html
# C:\Users\andre\OneDrive\Escritorio\Workspace\Python\EjerciciosFinales\ejemplo_directorio\archivo2.html
# Gracias por usar el buscador de archivos.
